# %% [markdown]
# # IS362 - Final Project
# ### Renting vs Buying a home in the United States

# %% [markdown]
# For my final project, I would like to provide statistics, pros and cons on ‘Renting vs Buying a home". Why I chose a particular topic is because in nowadays most people prefer renting instead of buying and investing in their own home.
#
# - I will provide and compare home rent/buy statistics for all 51 states
# - I will provide list of pros and cons on renting a home or apartment in the Unites States
# - I will provide list of pros and cons on buying home or apartment in The United States
# - I will provide some tableau analysis which will display data in more readable format.

# %% [markdown]
# ##### 1. Import

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from IPython.display import Image
import urllib.request
from datetime import date

# %% [markdown]
# ##### 2. Overal statistics on Renters vs Owners
# Based on the Pew Research Center analysis of Census Bureau housing data, since 1965, more and more houseowners rented their properties and the number of renters have grown really high. Between 2006 and 2016, the total number of households increased 7.6 million but the households headed by owners remained the same or slightly decreased because more houses have been rented.

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1511409007417' style='position: relative'><noscript><a href='#'><img alt='Renters vs Owners ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;RentersvsOwners&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='RentersvsOwners&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;RentersvsOwners&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1511409007417');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1511409007417' style='position: relative'><noscript><a href='#'><img alt='Renters vs Owners ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;RentersvsOwners&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='RentersvsOwners&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;RentersvsOwners&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>   
# ...

# %% [markdown]
# ##### Here is another way of showing the same data with more informations

# %%
RentvsBuyinUS = pd.read_csv('US_Renters&Owners.csv')
RentvsBuyinUS
# Out:
#   Type of Household   Households % of U.S. Total    Residents  \
# 0   Renter-Occupied   43,701,738             37%  111,118,927
# 1    Owner-Occupied   74,506,512             63%  202,228,998
# 2             Total  118,208,250            100%  313,347,925
#
#   % of U.S. Total.1
# 0               35%
# 1               65%
# 2              100%

# %%
labels = ('Renter-Occupied', 'Owner-Occupied')
sizes = [37.0, 63.0]
colors = ['Lightpink', 'LightGreen']
explode = (0.1, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3. Renter percentage, amount in a big cities compared to the amount of home owners
# In a big cities, most people prefer to live on rent because buying a house is almost impossible for middle income people. That's why people prefer to live on rent because they don't want to deal with maintenance fee, homeowners insurance fee, real estate tax and other fees. The closing cost of the house itself usually very high in big cities compared to smaller cities. For example: In New York, closing cost of the house is 20,000 dollars at least. However in Missouri, the closing cost will be around 6,500 dollars.

# %%
Big_city = pd.read_csv('Big_Cities_Housing_an_Rent.csv', header=None, usecols=[0, 1, 2, 3, 4], names=["City names","Population", "Housing", "Renters", "RenterPercent"])
Big_city = Big_city.reset_index().groupby("City names").aggregate(np.mean)
Big_city
# Out:
#                    index  Population  Housing  Renters  RenterPercent
# City names
# Austin, TX            10      931840   364893   136206           0.37
# Boston, MA            22      669469   261492    90822           0.35
# Charlotte, NC         16      827121   322872    86552           0.27
# Chicago, IL            2     2720556  1053229   316232           0.30
# Columbus, OH          13      849067   344839    93066           0.27
# Dallas, TX             8     1300082   495362   201599           0.41
# Denver, CO            18      682545   287074    93853           0.33
# Detroit, MI           20      677124   255580    48680           0.19
# El Paso, TX           19      681136   222557    40232           0.18
# Fort Worth, TX        15      836969   285173    60112           0.21
# Houston, TX            3     2298628   849974   346814           0.41
# Indianapolis, IN      14      848423   328431    75654           0.23
# ...

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1511417250861' style='position: relative'><noscript><a href='#'><img alt='Rent percentage in big cities ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;Rentpercentageinbigcities&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Rentpercentageinbigcities&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;Rentpercentageinbigcities&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1511417250861');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1511417250861' style='position: relative'><noscript><a href='#'><img alt='Rent percentage in big cities ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;Rentpercentageinbigcities&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Rentpercentageinbigcities&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Re&#47;Rentpercentageinbigcities&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='displ
# ...

# %% [markdown]
# ##### 4. Monthly mortgage vs rent by state

# %%
MonthlyMortgagevsRent = pd.read_csv('MonthlyMortgagevsRent.csv', header=None, usecols=[0, 1, 2, 3], names=["States","Median Monthly Mortgage", "Median Monthly Rent", "Difference"])
MonthlyMortgagevsRent
# Out:
#                   States  Median Monthly Mortgage  Median Monthly Rent  \
# 0             NEW JERSEY                     2349                 1214
# 1            CONNECTICUT                     2020                 1108
# 2   DISTRICT OF COLUMBIA                     2312                 1417
# 3          MASSACHUSETTS                     2048                 1164
# 4               NEW YORK                     2009                 1173
# 5             CALIFORNIA                     2123                 1311
# 6          NEW HAMPSHIRE                     1828                 1017
# 7           RHODE ISLAND                     1730                  938
# 8                 HAWAII                     2248                 1500
# 9                 ALASKA                     1817                 1163
# 10              ILLINOIS                     1588                  936
# 11              MARYLAND                     1909                 1278
# ...

# %%
MonthlyMortgagevsRent.plot.bar(fontsize=10,figsize= (50, 10))

# %% [markdown]
# Let's now see how much difference we will see between monthly rent and mortgage payments in each state. I believe, if the difference is about 500 dollars than people should buy a house because house is investment.

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1511585454991' style='position: relative'><noscript><a href='#'><img alt='Monthly difference Mortgage vs Rent ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9T&#47;9TMRQKMR9&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;9TMRQKMR9' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9T&#47;9TMRQKMR9&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1511585454991');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1511585454991' style='position: relative'><noscript><a href='#'><img alt='Monthly difference Mortgage vs Rent ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9T&#47;9TMRQKMR9&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;9TMRQKMR9' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9T&#47;9TMRQKMR9&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = documen
# ...

# %% [markdown]
# ##### 5. Pros and Cons of Buying vs Renting
#
# ###### Buying:
#
# Proc
# * Building Equity Over Time
# * Tax Benefits
# * Potential for Rental Income
# * More Creative Freedom
# * Sense of Belonging and Community
#
# Cons
# * Potential for Financial Loss
# * Responsibility for Maintenance and Repairs
# * Most Homes Aren’t Sold Furnished
# * High Upfront Costs
#
# ###### Renting:
#
# Pros
# * No Responsibility for Maintenance or Repairs
# * Relocating Is Easier
# * No Exposure to Real Estate Market
# * Credit Requirements Generally Less Strict
# * Some Utilities May Be Included
#
# Cons
# * No Equity Building
# * No Federal Tax Benefits
# * Limited Control Over Ongoing Housing Costs
# * Limited Housing Security

# %% [markdown]
# ##### 6. Conclusion
# Based on Pewresearch, people whose age is younger than 35 most likely would rent an apartment or house because it is the age where people try finish their school and get their degree, work on less paying jobs in the hopes of getting a better job in the future. School is a big factor where all the money goes and than building a family is also a big expence. Until people whose age is less than 35 collect money to buy a house, their preference would be renting and moving quickly if they find a better job.
# In my opinion, buying a house is always better because it is investment which grows every year.

# %% [markdown]
# ##### 7. Sources:
# - http://www.pewresearch.org/fact-tank/2017/07/19/more-u-s-households-are-renting-than-at-any-point-in-50-years/
# - http://www.nmhc.org/Content.aspx?id=4708#RentOwn
# - https://www.moneycrashers.com/rent-or-buy-a-house/
